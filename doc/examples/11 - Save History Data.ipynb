# %%
# 导入所需库
import ccxt
import pandas as pd
import datetime
import time
import os

# %%
def save_spot_candle_data_from_exchange(exchange, symbol, time_interval, start_time, path):
    """
    从交易所获取并保存指定日期和交易对的K线数据
    返回: (DataFrame, bool) - 数据框和是否为空数据的标志
    """
    df_list = []
    start_time_since = exchange.parse8601(start_time)
    end_time = pd.to_datetime(start_time) + datetime.timedelta(days=1)

    while True:
        try:
            # 获取K线数据
            klines = exchange.fetch_ohlcv(
                symbol=symbol, 
                timeframe=time_interval, 
                since=start_time_since
            )
            if not klines:
                break
                
            # 创建DataFrame，保持与官方API完全一致的处理方式
            df = pd.DataFrame(klines)
            # 只保留前6列（与官方API一致）
            if len(df.columns) > 6:
                df = df.iloc[:, :6]
            
            df_list.append(df)
            
            last_timestamp = df.iloc[-1][0]  # 第一列是时间戳
            start_time_since = int(last_timestamp) + 1
            
            if pd.to_datetime(last_timestamp, unit='ms') >= end_time or df.shape[0] <= 1:
                break
                
            time.sleep(0.5)
            
        except Exception as e:
            print(f"获取数据出错: {e}")
            time.sleep(3)
            continue

    if not df_list:
        return pd.DataFrame(), True  # 返回空DataFrame和空数据标志
    
    # 合并数据
    df = pd.concat(df_list, ignore_index=True)
    
    # 完全按照官方API的方式处理数据
    df.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume']
    
    # 使用完全相同的数据类型转换方式
    df['datetime'] = df['datetime'].values.astype(dtype='datetime64[ms]')
    df['open'] = df['open'].values.astype(float)
    df['high'] = df['high'].values.astype(float)
    df['low'] = df['low'].values.astype(float)
    df['close'] = df['close'].values.astype(float)
    df['volume'] = df['volume'].values.astype(float)
    
    # 筛选当天数据
    target_date = pd.to_datetime(start_time).date()
    df = df[df['datetime'].dt.date == target_date]
    
    # 数据清理
    df = df.drop_duplicates(subset=['datetime'], keep='last')\
           .sort_values('datetime')\
           .reset_index(drop=True)
    
    # 保存数据
    if not df.empty:
        date_str = str(pd.to_datetime(start_time).date())
        date_path = os.path.join(path, date_str)
        os.makedirs(date_path, exist_ok=True)
        
        file_name = f"{date_str}_{symbol.replace('/', '')}_{time_interval}.csv"
        full_path = os.path.join(date_path, file_name)
        
        df.to_csv(full_path, index=False)
        print(f"数据已保存至: {full_path}")
    
    return df, False  # 返回数据和非空数据标志

# %%
# 设置数据获取参数
params = {
    # 数据获取配置
    'begin_date': '2024-01-01',
    'end_date': '2025-01-01',
    'time_intervals': ['1m'],  # 可选: ['1m', '5m', '15m', '1h', '4h', '1d']
    'use_all_usdt_pairs': False,  # 设置为True则获取所有USDT交易对，False则使用指定交易对
    'specific_symbols': ['KAS/USDT'],  # 当use_all_usdt_pairs为False时使用
    'base_path': r'\\znas\Main\spot',  # 指定数据保存的根目录
    
    # 代理配置
    'proxy': {
        'host': '127.0.0.1',
        'port': 2206
    },
    
    # 交易所基础配置
    'exchange_config': {
        'timeout': 5000,
        'enableRateLimit': False
    }
}


# 确保根目录存在
os.makedirs(params['base_path'], exist_ok=True)

# %%
# 生成日期列表
def generate_date_list(begin_date, end_date):
    date_list = []
    date = pd.to_datetime(begin_date)
    while date <= pd.to_datetime(end_date):
        date_list.append(str(date))
        date += datetime.timedelta(days=1)
    return date_list

date_list = generate_date_list(params['begin_date'], params['end_date'])
print(f"将获取从 {date_list[0]} 到 {date_list[-1]} 的数据")
# Out:
# 将获取从 2024-01-01 00:00:00 到 2025-01-01 00:00:00 的数据

# %%
def initialize_exchange_and_markets(params):
    """
    初始化交易所并加载市场数据
    """
    # 添加代理配置到交易所配置中
    proxy_url = f"http://{params['proxy']['host']}:{params['proxy']['port']}"
    params['exchange_config']['proxies'] = {
        'http': proxy_url,
        'https': proxy_url
    }
    
    # 初始化交易所
    exchange = ccxt.binance(params['exchange_config'])
    
    # 加载市场数据
    while True:
        try:
            market = exchange.load_markets()
            print('市场数据加载成功')
            
            # 处理交易对
            market_df = pd.DataFrame(market).T
            all_symbols = list(market_df['symbol'])
            
            if params['use_all_usdt_pairs']:
                target_symbols = [symbol for symbol in all_symbols if symbol.endswith('/USDT')]
            else:
                target_symbols = params['specific_symbols']
                
            print(f"将获取以下交易对的数据：{target_symbols}")
            print(f"共 {len(target_symbols)} 个交易对")
            
            return exchange, target_symbols
            
        except Exception as e:
            print(f'加载市场数据失败: {e}')
            time.sleep(3)

# 初始化交易所并获取交易对
exchange, target_symbols = initialize_exchange_and_markets(params)
# Out:
# 市场数据加载成功
# 将获取以下交易对的数据：['KAS/USDT']
# 共 1 个交易对

# %%
# 在主循环之前，添加预扫描函数
def scan_existing_files(base_path):
    """预扫描已存在的文件"""
    existing_files = set()
    for root, _, files in os.walk(base_path):
        for file in files:
            if file.endswith('.csv'):
                existing_files.add(file)
    print(f"已扫描到 {len(existing_files)} 个现有文件")
    return existing_files

# 获取现有文件列表
existing_files = scan_existing_files(params['base_path'])

# 添加统计函数
def analyze_download_status(target_symbols, existing_files, date_list, time_intervals):
    """分析每个交易对的下载情况"""
    stats = {}
    for symbol in target_symbols:
        stats[symbol] = {
            'total_expected': len(date_list) * len(time_intervals),
            'downloaded': 0,
            'missing_dates': []
        }
        
        for start_time in date_list:
            for time_interval in time_intervals:
                date_str = str(pd.to_datetime(start_time).date())
                file_name = f"{date_str}_{symbol.replace('/', '')}_{time_interval}.csv"
                if file_name in existing_files:
                    stats[symbol]['downloaded'] += 1
                else:
                    stats[symbol]['missing_dates'].append(f"{date_str}_{time_interval}")

    # 打印统计信息
    print("\n下载统计信息:")
    incomplete_symbols = []
    for symbol, data in stats.items():
        completion_rate = (data['downloaded'] / data['total_expected']) * 100
        print(f"{symbol}: 完成率 {completion_rate:.2f}% ({data['downloaded']}/{data['total_expected']})")
        if data['downloaded'] < data['total_expected']:
            incomplete_symbols.append(symbol)
            if len(data['missing_dates']) <= 10:  # 只显示前10个缺失日期
                print(f"  缺失数据: {data['missing_dates'][:10]}")
            else:
                print(f"  缺失数据过多，共{len(data['missing_dates'])}个日期")

    print(f"\n未完全下载的交易对数量: {len(incomplete_symbols)}/{len(target_symbols)}")
    return incomplete_symbols

# 在主循环结束后添加分析
print("\n开始分析下载情况...")
existing_files = scan_existing_files(params['base_path'])  # 重新扫描一次
incomplete_symbols = analyze_download_status(
    target_symbols, 
    existing_files, 
    date_list, 
    params['time_intervals']
)

# 如果需要，可以只针对未完成的交易对重新下载
if incomplete_symbols:
    print("\n是否要重新下载未完成的交易对？(y/n)")
    if input().lower() == 'y':
        # 更新target_symbols为未完成的交易对
        target_symbols = incomplete_symbols
        
# 主循环部分
error_list = []
empty_data_count = {}  # 用于记录每个交易对的连续空数据天数

# 反转日期列表，从最新日期开始获取
date_list.reverse()

for symbol in target_symbols:
    empty_data_count[symbol] = 0
    
    for start_time in date_list:
        if empty_data_count[symbol] >= 3:
            print(f'{symbol} 连续 {empty_data_count[symbol]} 天无数据，跳转到下一个交易对')
            break
            
        for time_interval in params['time_intervals']:
            try:
                # 直接检查文件名是否在集合中
                date_str = str(pd.to_datetime(start_time).date())
                file_name = f"{date_str}_{symbol.replace('/', '')}_{time_interval}.csv"
                
                if file_name in existing_files:
                    print(f"文件 {file_name} 已存在，跳过下载")
                    empty_data_count[symbol] = 0  # 重置计数器
                    continue
                
                # 如果文件不存在，则下载数据
                print(f'正在获取 {exchange.id} {symbol} {time_interval} {start_time} 的数据')
                df, is_empty = save_spot_candle_data_from_exchange(
                    exchange=exchange,
                    symbol=symbol,
                    time_interval=time_interval,
                    start_time=f'{start_time} 00:00:00',
                    path=params['base_path']
                )
                
                if is_empty or (isinstance(df, pd.DataFrame) and df.empty):
                    empty_data_count[symbol] += 1
                    print(f'{symbol} 连续 {empty_data_count[symbol]} 天无数据')
                    if empty_data_count[symbol] >= 3:
                        print(f'达到连续空数据阈值，跳转到下一个交易对')
                        break
                else:
                    empty_data_count[symbol] = 0
                    print(f'成功下载并保存 {symbol} 在 {start_time} 的数据，数据形状: {df.shape}')
                
            except Exception as e:
                error_msg = f'{exchange.id}_{symbol}_{time_interval}_{start_time}'
                print(f'获取数据失败: {error_msg}, 错误: {e}')
                error_list.append(error_msg)
                
            time.sleep(0.5)
            
        if empty_data_count[symbol] >= 3:
            break
# Out:
# 已扫描到 0 个现有文件
#
# 开始分析下载情况...
# 已扫描到 0 个现有文件
#
# 下载统计信息:
# KAS/USDT: 完成率 0.00% (0/367)
#   缺失数据过多，共367个日期
#
# 未完全下载的交易对数量: 1/1
#
# 是否要重新下载未完成的交易对？(y/n)
# 正在获取 binance KAS/USDT 1m 2025-01-01 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2025-01-01\2025-01-01_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2025-01-01 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-31 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-31\2024-12-31_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-31 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-30 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-30\2024-12-30_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-30 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-29 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-29\2024-12-29_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-29 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-28 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-28\2024-12-28_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-28 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-27 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-27\2024-12-27_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-27 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-26 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-26\2024-12-26_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-26 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-25 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-25\2024-12-25_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-25 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-24 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-24\2024-12-24_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-24 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-23 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-23\2024-12-23_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-23 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-22 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-22\2024-12-22_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-22 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-21 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-21\2024-12-21_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-21 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-20 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-20\2024-12-20_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-20 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-19 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-19\2024-12-19_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-19 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-18 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-18\2024-12-18_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-18 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-17 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-17\2024-12-17_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-17 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-16 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-16\2024-12-16_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-16 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-15 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-15\2024-12-15_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-15 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-14 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-14\2024-12-14_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-14 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-13 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-13\2024-12-13_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-13 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-12 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-12\2024-12-12_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-12 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-11 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-11\2024-12-11_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-11 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-10 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-10\2024-12-10_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-10 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-09 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-09\2024-12-09_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-09 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-08 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-08\2024-12-08_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-08 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-07 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-07\2024-12-07_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-07 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-06 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-06\2024-12-06_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-06 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-05 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-05\2024-12-05_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-05 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-04 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-04\2024-12-04_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-04 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-03 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-03\2024-12-03_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-03 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-02 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-02\2024-12-02_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-02 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-12-01 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-12-01\2024-12-01_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-12-01 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-30 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-30\2024-11-30_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-30 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-29 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-29\2024-11-29_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-29 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-28 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-28\2024-11-28_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-28 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-27 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-27\2024-11-27_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-27 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-26 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-26\2024-11-26_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-26 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-25 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-25\2024-11-25_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-25 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-24 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-24\2024-11-24_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-24 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-23 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-23\2024-11-23_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-23 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-22 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-22\2024-11-22_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-22 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-21 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-21\2024-11-21_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-21 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-20 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-20\2024-11-20_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-20 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-19 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-19\2024-11-19_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-19 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-18 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-18\2024-11-18_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-18 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-17 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-17\2024-11-17_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-17 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-16 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-16\2024-11-16_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-16 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-15 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-15\2024-11-15_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-15 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-14 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-14\2024-11-14_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-14 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-13 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-13\2024-11-13_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-13 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-12 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-12\2024-11-12_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-12 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-11 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-11\2024-11-11_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-11 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-10 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-10\2024-11-10_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-10 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-09 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-09\2024-11-09_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-09 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-08 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-08\2024-11-08_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-08 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-07 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-07\2024-11-07_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-07 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-06 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-06\2024-11-06_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-06 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-05 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-05\2024-11-05_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-05 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-04 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-04\2024-11-04_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-04 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-03 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-03\2024-11-03_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-03 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-02 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-02\2024-11-02_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-02 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-11-01 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-11-01\2024-11-01_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-11-01 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-31 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-31\2024-10-31_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-31 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-30 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-30\2024-10-30_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-30 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-29 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-29\2024-10-29_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-29 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-28 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-28\2024-10-28_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-28 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-27 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-27\2024-10-27_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-27 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-26 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-26\2024-10-26_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-26 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-25 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-25\2024-10-25_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-25 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-24 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-24\2024-10-24_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-24 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-23 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-23\2024-10-23_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-23 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-22 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-22\2024-10-22_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-22 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-21 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-21\2024-10-21_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-21 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-20 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-20\2024-10-20_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-20 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-19 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-19\2024-10-19_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-19 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-18 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-18\2024-10-18_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-18 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-17 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-17\2024-10-17_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-17 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-16 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-16\2024-10-16_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-16 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-15 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-15\2024-10-15_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-15 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-14 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-14\2024-10-14_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-14 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-13 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-13\2024-10-13_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-13 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-12 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-12\2024-10-12_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-12 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-11 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-11\2024-10-11_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-11 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-10 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-10\2024-10-10_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-10 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-09 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-09\2024-10-09_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-09 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-08 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-08\2024-10-08_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-08 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-07 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-07\2024-10-07_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-07 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-06 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-06\2024-10-06_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-06 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-05 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-05\2024-10-05_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-05 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-04 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-04\2024-10-04_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-04 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-03 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-03\2024-10-03_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-03 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-02 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-02\2024-10-02_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-02 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-10-01 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-10-01\2024-10-01_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-10-01 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-30 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-30\2024-09-30_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-30 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-29 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-29\2024-09-29_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-29 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-28 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-28\2024-09-28_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-28 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-27 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-27\2024-09-27_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-27 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-26 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-26\2024-09-26_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-26 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-25 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-25\2024-09-25_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-25 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-24 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-24\2024-09-24_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-24 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-23 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-23\2024-09-23_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-23 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-22 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-22\2024-09-22_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-22 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-21 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-21\2024-09-21_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-21 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-20 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-20\2024-09-20_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-20 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-19 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-19\2024-09-19_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-19 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-18 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-18\2024-09-18_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-18 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-17 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-17\2024-09-17_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-17 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-16 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-16\2024-09-16_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-16 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-15 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-15\2024-09-15_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-15 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-14 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-14\2024-09-14_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-14 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-13 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-13\2024-09-13_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-13 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-12 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-12\2024-09-12_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-12 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-11 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-11\2024-09-11_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-11 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-10 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-10\2024-09-10_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-10 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-09 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-09\2024-09-09_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-09 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-08 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-08\2024-09-08_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-08 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-07 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-07\2024-09-07_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-07 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-06 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-06\2024-09-06_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-06 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-05 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-05\2024-09-05_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-05 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-04 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-04\2024-09-04_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-04 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-03 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-03\2024-09-03_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-03 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-02 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-02\2024-09-02_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-02 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-09-01 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-09-01\2024-09-01_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-09-01 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-31 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-31\2024-08-31_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-31 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-30 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-30\2024-08-30_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-30 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-29 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-29\2024-08-29_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-29 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-28 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-28\2024-08-28_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-28 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-27 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-27\2024-08-27_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-27 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-26 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-26\2024-08-26_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-26 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-25 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-25\2024-08-25_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-25 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-24 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-24\2024-08-24_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-24 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-23 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-23\2024-08-23_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-23 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-22 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-22\2024-08-22_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-22 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-21 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-21\2024-08-21_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-21 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-20 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-20\2024-08-20_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-20 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-19 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-19\2024-08-19_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-19 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-18 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-18\2024-08-18_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-18 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-17 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-17\2024-08-17_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-17 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-16 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-16\2024-08-16_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-16 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-15 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-15\2024-08-15_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-15 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-14 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-14\2024-08-14_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-14 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-13 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-13\2024-08-13_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-13 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-12 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-12\2024-08-12_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-12 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-11 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-11\2024-08-11_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-11 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-10 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-10\2024-08-10_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-10 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-09 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-09\2024-08-09_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-09 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-08 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-08\2024-08-08_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-08 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-07 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-07\2024-08-07_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-07 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-06 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-06\2024-08-06_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-06 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-05 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-05\2024-08-05_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-05 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-04 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-04\2024-08-04_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-04 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-03 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-03\2024-08-03_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-03 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-02 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-02\2024-08-02_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-02 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-08-01 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-08-01\2024-08-01_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-08-01 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-31 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-31\2024-07-31_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-31 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-30 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-30\2024-07-30_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-30 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-29 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-29\2024-07-29_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-29 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-28 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-28\2024-07-28_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-28 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-27 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-27\2024-07-27_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-27 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-26 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-26\2024-07-26_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-26 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-25 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-25\2024-07-25_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-25 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-24 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-24\2024-07-24_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-24 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-23 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-23\2024-07-23_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-23 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-22 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-22\2024-07-22_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-22 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-21 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-21\2024-07-21_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-21 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-20 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-20\2024-07-20_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-20 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-19 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-19\2024-07-19_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-19 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-18 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-18\2024-07-18_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-18 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-17 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-17\2024-07-17_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-17 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-16 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-16\2024-07-16_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-16 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-15 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-15\2024-07-15_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-15 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-14 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-14\2024-07-14_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-14 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-13 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-13\2024-07-13_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-13 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-12 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-12\2024-07-12_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-12 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-11 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-11\2024-07-11_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-11 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-10 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-10\2024-07-10_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-10 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-09 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-09\2024-07-09_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-09 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-08 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-08\2024-07-08_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-08 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-07 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-07\2024-07-07_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-07 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-06 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-06\2024-07-06_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-06 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-05 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-05\2024-07-05_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-05 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-04 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-04\2024-07-04_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-04 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-03 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-03\2024-07-03_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-03 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-02 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-02\2024-07-02_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-02 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-07-01 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-07-01\2024-07-01_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-07-01 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-30 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-30\2024-06-30_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-30 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-29 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-29\2024-06-29_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-29 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-28 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-28\2024-06-28_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-28 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-27 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-27\2024-06-27_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-27 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-26 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-26\2024-06-26_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-26 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-25 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-25\2024-06-25_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-25 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-24 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-24\2024-06-24_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-24 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-23 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-23\2024-06-23_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-23 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-22 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-22\2024-06-22_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-22 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-21 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-21\2024-06-21_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-21 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-20 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-20\2024-06-20_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-20 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-19 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-19\2024-06-19_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-19 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-18 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-18\2024-06-18_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-18 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-17 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-17\2024-06-17_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-17 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-16 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-16\2024-06-16_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-16 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-15 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-15\2024-06-15_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-15 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-14 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-14\2024-06-14_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-14 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-13 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-13\2024-06-13_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-13 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-12 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-12\2024-06-12_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-12 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-11 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-11\2024-06-11_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-11 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-10 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-10\2024-06-10_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-10 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-09 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-09\2024-06-09_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-09 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-08 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-08\2024-06-08_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-08 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-07 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-07\2024-06-07_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-07 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-06 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-06\2024-06-06_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-06 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-05 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-05\2024-06-05_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-05 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-04 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-04\2024-06-04_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-04 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-03 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-03\2024-06-03_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-03 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-02 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-02\2024-06-02_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-02 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-06-01 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-06-01\2024-06-01_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-06-01 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-31 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-31\2024-05-31_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-31 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-30 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-30\2024-05-30_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-30 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-29 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-29\2024-05-29_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-29 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-28 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-28\2024-05-28_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-28 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-27 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-27\2024-05-27_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-27 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-26 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-26\2024-05-26_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-26 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-25 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-25\2024-05-25_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-25 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-24 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-24\2024-05-24_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-24 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-23 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-23\2024-05-23_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-23 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-22 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-22\2024-05-22_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-22 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-21 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-21\2024-05-21_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-21 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-20 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-20\2024-05-20_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-20 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-19 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-19\2024-05-19_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-19 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-18 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-18\2024-05-18_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-18 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-17 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-17\2024-05-17_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-17 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-16 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-16\2024-05-16_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-16 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-15 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-15\2024-05-15_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-15 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-14 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-14\2024-05-14_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-14 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-13 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-13\2024-05-13_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-13 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-12 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-12\2024-05-12_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-12 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-11 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-11\2024-05-11_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-11 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-10 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-10\2024-05-10_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-10 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-09 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-09\2024-05-09_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-09 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-08 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-08\2024-05-08_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-08 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-07 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-07\2024-05-07_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-07 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-06 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-06\2024-05-06_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-06 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-05 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-05\2024-05-05_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-05 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-04 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-04\2024-05-04_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-04 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-03 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-03\2024-05-03_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-03 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-02 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-02\2024-05-02_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-02 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-05-01 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-05-01\2024-05-01_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-05-01 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-30 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-30\2024-04-30_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-30 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-29 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-29\2024-04-29_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-29 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-28 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-28\2024-04-28_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-28 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-27 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-27\2024-04-27_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-27 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-26 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-26\2024-04-26_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-26 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-25 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-25\2024-04-25_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-25 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-24 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-24\2024-04-24_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-24 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-23 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-23\2024-04-23_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-23 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-22 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-22\2024-04-22_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-22 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-21 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-21\2024-04-21_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-21 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-20 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-20\2024-04-20_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-20 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-19 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-19\2024-04-19_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-19 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-18 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-18\2024-04-18_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-18 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-17 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-17\2024-04-17_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-17 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-16 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-16\2024-04-16_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-16 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-15 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-15\2024-04-15_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-15 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-14 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-14\2024-04-14_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-14 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-13 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-13\2024-04-13_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-13 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-12 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-12\2024-04-12_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-12 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-11 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-11\2024-04-11_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-11 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-10 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-10\2024-04-10_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-10 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-09 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-09\2024-04-09_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-09 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-08 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-08\2024-04-08_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-08 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-07 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-07\2024-04-07_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-07 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-06 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-06\2024-04-06_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-06 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-05 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-05\2024-04-05_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-05 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-04 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-04\2024-04-04_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-04 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-03 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-03\2024-04-03_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-03 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-02 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-02\2024-04-02_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-02 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-04-01 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-04-01\2024-04-01_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-04-01 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-31 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-31\2024-03-31_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-31 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-30 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-30\2024-03-30_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-30 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-29 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-29\2024-03-29_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-29 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-28 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-28\2024-03-28_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-28 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-27 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-27\2024-03-27_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-27 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-26 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-26\2024-03-26_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-26 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-25 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-25\2024-03-25_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-25 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-24 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-24\2024-03-24_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-24 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-23 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-23\2024-03-23_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-23 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-22 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-22\2024-03-22_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-22 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-21 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-21\2024-03-21_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-21 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-20 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-20\2024-03-20_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-20 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-19 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-19\2024-03-19_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-19 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-18 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-18\2024-03-18_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-18 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-17 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-17\2024-03-17_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-17 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-16 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-16\2024-03-16_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-16 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-15 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-15\2024-03-15_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-15 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-14 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-14\2024-03-14_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-14 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-13 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-13\2024-03-13_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-13 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-12 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-12\2024-03-12_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-12 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-11 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-11\2024-03-11_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-11 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-10 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-10\2024-03-10_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-10 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-09 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-09\2024-03-09_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-09 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-08 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-08\2024-03-08_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-08 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-07 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-07\2024-03-07_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-07 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-06 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-06\2024-03-06_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-06 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-05 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-05\2024-03-05_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-05 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-04 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-04\2024-03-04_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-04 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-03 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-03\2024-03-03_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-03 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-02 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-02\2024-03-02_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-02 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-03-01 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-03-01\2024-03-01_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-03-01 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-29 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-29\2024-02-29_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-29 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-28 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-28\2024-02-28_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-28 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-27 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-27\2024-02-27_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-27 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-26 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-26\2024-02-26_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-26 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-25 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-25\2024-02-25_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-25 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-24 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-24\2024-02-24_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-24 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-23 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-23\2024-02-23_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-23 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-22 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-22\2024-02-22_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-22 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-21 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-21\2024-02-21_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-21 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-20 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-20\2024-02-20_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-20 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-19 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-19\2024-02-19_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-19 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-18 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-18\2024-02-18_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-18 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-17 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-17\2024-02-17_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-17 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-16 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-16\2024-02-16_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-16 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-15 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-15\2024-02-15_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-15 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-14 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-14\2024-02-14_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-14 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-13 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-13\2024-02-13_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-13 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-12 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-12\2024-02-12_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-12 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-11 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-11\2024-02-11_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-11 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-10 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-10\2024-02-10_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-10 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-09 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-09\2024-02-09_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-09 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-08 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-08\2024-02-08_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-08 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-07 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-07\2024-02-07_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-07 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-06 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-06\2024-02-06_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-06 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-05 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-05\2024-02-05_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-05 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-04 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-04\2024-02-04_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-04 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-03 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-03\2024-02-03_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-03 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-02 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-02\2024-02-02_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-02 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-02-01 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-02-01\2024-02-01_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-02-01 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-31 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-31\2024-01-31_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-31 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-30 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-30\2024-01-30_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-30 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-29 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-29\2024-01-29_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-29 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-28 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-28\2024-01-28_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-28 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-27 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-27\2024-01-27_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-27 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-26 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-26\2024-01-26_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-26 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-25 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-25\2024-01-25_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-25 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-24 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-24\2024-01-24_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-24 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-23 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-23\2024-01-23_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-23 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-22 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-22\2024-01-22_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-22 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-21 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-21\2024-01-21_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-21 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-20 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-20\2024-01-20_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-20 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-19 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-19\2024-01-19_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-19 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-18 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-18\2024-01-18_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-18 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-17 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-17\2024-01-17_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-17 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-16 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-16\2024-01-16_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-16 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-15 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-15\2024-01-15_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-15 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-14 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-14\2024-01-14_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-14 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-13 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-13\2024-01-13_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-13 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-12 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-12\2024-01-12_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-12 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-11 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-11\2024-01-11_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-11 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-10 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-10\2024-01-10_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-10 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-09 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-09\2024-01-09_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-09 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-08 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-08\2024-01-08_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-08 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-07 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-07\2024-01-07_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-07 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-06 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-06\2024-01-06_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-06 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-05 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-05\2024-01-05_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-05 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-04 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-04\2024-01-04_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-04 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-03 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-03\2024-01-03_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-03 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-02 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-02\2024-01-02_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-02 00:00:00 的数据，数据形状: (1440, 6)
# 正在获取 binance KAS/USDT 1m 2024-01-01 00:00:00 的数据
# 数据已保存至: \\znas\Main\future\2024-01-01\2024-01-01_KASUSDT_1m.csv
# 成功下载并保存 KAS/USDT 在 2024-01-01 00:00:00 的数据，数据形状: (1440, 6)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# 显示执行结果
print('数据获取完成')
if error_list:
    print('\n获取失败的数据:')
    for error in error_list:
        print(error)
else:
    print('\n所有数据获取成功！')
# Out:
# 数据获取完成
#
# 所有数据获取成功！
