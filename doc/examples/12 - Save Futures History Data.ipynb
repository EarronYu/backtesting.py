# %% [markdown]
# # 保存币安合约历史数据
#
# 本文档用于下载和保存币安合约的历史K线数据。

# %%
import ccxt
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import time
import os
import json
from tqdm import tqdm

# %%
# 设置数据获取参数
params = {
    # 数据获取配置
    'begin_date': '2025-02-05',
    'end_date': '2025-02-08',
    'time_intervals': ['1m'],  # 可选: ['1m', '5m', '15m', '1h', '4h', '1d']
    'use_all_usdt_pairs': True,  # 设置为True则获取所有USDT交易对
    'specific_symbols': ['KAS/USDT:USDT'],  # 当use_all_usdt_pairs为False时使用
    'base_path': r'\\znas\Main\futures',  # 指定数据保存的根目录
    
    # 代理配置
    'proxy': {
        'host': '127.0.0.1',
        'port': 1913
    },
    
    # 交易所基础配置
    'exchange_config': {
        'timeout': 5000,
        'enableRateLimit': False,
        'options': {
            'defaultType': 'future'  # 设置为合约模式
        }
    }
}

# 确保根目录存在
os.makedirs(params['base_path'], exist_ok=True)

# 生成日期列表
start_date = datetime.strptime(params['begin_date'], '%Y-%m-%d')
end_date = datetime.strptime(params['end_date'], '%Y-%m-%d')
date_list = pd.date_range(start=start_date, end=end_date, freq='D').strftime('%Y-%m-%d').tolist()

# %%
def scan_existing_files(base_path):
    """预扫描已存在的文件"""
    existing_files = set()
    for root, _, files in os.walk(base_path):
        for file in files:
            if file.endswith('.csv'):
                existing_files.add(file)
    print(f"已扫描到 {len(existing_files)} 个现有文件")
    return existing_files

def analyze_download_status(target_symbols, existing_files, date_list, time_intervals):
    """分析每个交易对的下载情况"""
    stats = {}
    for symbol in target_symbols:
        stats[symbol] = {
            'total_expected': len(date_list) * len(time_intervals),
            'downloaded': 0,
            'missing_dates': []
        }
        
        for start_time in date_list:
            for time_interval in time_intervals:
                date_str = str(pd.to_datetime(start_time).date())
                file_name = f"{date_str}_{symbol.replace('/', '_').replace(':', '_')}_{time_interval}.csv"
                if file_name in existing_files:
                    stats[symbol]['downloaded'] += 1
                else:
                    stats[symbol]['missing_dates'].append(f"{date_str}_{time_interval}")

    print("\n下载统计信息:")
    incomplete_symbols = []
    for symbol, data in stats.items():
        completion_rate = (data['downloaded'] / data['total_expected']) * 100
        print(f"{symbol}: 完成率 {completion_rate:.2f}% ({data['downloaded']}/{data['total_expected']})")
        if data['downloaded'] < data['total_expected']:
            incomplete_symbols.append(symbol)
            if len(data['missing_dates']) <= 10:
                print(f"  缺失数据: {data['missing_dates'][:10]}")
            else:
                print(f"  缺失数据过多，共{len(data['missing_dates'])}个日期")

    print(f"\n未完全下载的交易对数量: {len(incomplete_symbols)}/{len(target_symbols)}")
    return incomplete_symbols

# %%
def init_exchange():
    """初始化交易所接口"""
    config = {
        **params['exchange_config'],
        'proxies': {
            'http': f"http://{params['proxy']['host']}:{params['proxy']['port']}",
            'https': f"http://{params['proxy']['host']}:{params['proxy']['port']}"
        }
    }
    return ccxt.binance(config)

exchange = init_exchange()

# %%
def get_available_symbols():
    """获取可用的交易对列表"""
    if params['use_all_usdt_pairs']:
        markets = exchange.load_markets()
        return [symbol for symbol in markets.keys() if ':USDT' in symbol]
    else:
        return params['specific_symbols']

def fetch_and_save_data(symbol, timeframe, start_time):
    """获取并保存单个交易对的数据"""
    try:
        # 构建文件名和路径
        date_str = str(pd.to_datetime(start_time).date())
        date_path = os.path.join(params['base_path'], date_str)
        os.makedirs(date_path, exist_ok=True)
        
        file_name = f"{date_str}_{symbol.replace('/', '').replace(':', '_')}_{timeframe}.csv"
        save_path = os.path.join(date_path, file_name)
        
        # 如果文件已存在，跳过
        if os.path.exists(save_path):
            # print(f"文件 {file_name} 已存在，跳过下载")
            return True, None
        
        # 获取数据
        print(f'正在获取 {exchange.id} {symbol} {timeframe} {start_time} 的数据')
        since = int(pd.Timestamp(f'{start_time} 00:00:00').timestamp() * 1000)
        end = int(pd.Timestamp(f'{start_time} 23:59:59').timestamp() * 1000)
        
        all_data = []
        current_since = since
        
        while current_since < end:
            data = exchange.fetch_ohlcv(
                symbol=symbol,
                timeframe=timeframe,
                since=current_since,
                limit=1000
            )
            
            if not data:
                break
                
            all_data.extend(data)
            current_since = data[-1][0] + 1
            time.sleep(0.8)
        
        if not all_data:
            print(f"{symbol} 在 {start_time} 无数据")
            return False, None
            
        # 转换为DataFrame并保存
        df = pd.DataFrame(
            all_data,
            columns=['datetime', 'open', 'high', 'low', 'close', 'volume']
        )
        df['datetime'] = pd.to_datetime(df['datetime'], unit='ms')
        
        # 筛选当天数据
        target_date = pd.to_datetime(start_time).date()
        df = df[df['datetime'].dt.date == target_date]
        
        # 数据清理
        df = df.drop_duplicates(subset=['datetime'], keep='last')\
               .sort_values('datetime')\
               .reset_index(drop=True)
        
        if not df.empty:
            df.to_csv(save_path, index=False)
            # print(f'成功下载并保存 {symbol} 在 {start_time} 的数据，数据形状: {df.shape}')
            return True, df
        else:
            print(f"{symbol} 在 {start_time} 筛选后无数据")
            return False, None
        
    except Exception as e:
        print(f'获取数据失败: {symbol}_{timeframe}_{start_time}, 错误: {e}')
        return False, None

# %%
# 获取现有文件列表
existing_files = scan_existing_files(params['base_path'])

# 获取要处理的交易对
target_symbols = get_available_symbols()
print(f"将处理以下交易对: {target_symbols}")

# 主循环
error_list = []
empty_data_count = {}  # 用于记录每个交易对的连续空数据天数

# 反转日期列表，从最新日期开始获取
date_list.reverse()

for symbol in target_symbols:
    empty_data_count[symbol] = 0
    
    for start_time in date_list:
        if empty_data_count[symbol] >= 3:
            print(f'{symbol} 连续 {empty_data_count[symbol]} 天无数据，跳转到下一个交易对')
            break
            
        for time_interval in params['time_intervals']:
            success, df = fetch_and_save_data(symbol, time_interval, start_time)
            
            if not success:
                error_msg = f'{exchange.id}_{symbol}_{time_interval}_{start_time}'
                error_list.append(error_msg)
                empty_data_count[symbol] += 1
            else:
                empty_data_count[symbol] = 0
                
        if empty_data_count[symbol] >= 3:
            break

# 分析下载情况
print("\n开始分析下载情况...")
existing_files = scan_existing_files(params['base_path'])  # 重新扫描
incomplete_symbols = analyze_download_status(
    target_symbols,
    existing_files,
    date_list,
    params['time_intervals']
)

# 询问是否重新下载未完成的交易对
if incomplete_symbols:
    print("\n是否要重新下载未完成的交易对？(y/n)")
    if input().lower() == 'y':
        target_symbols = incomplete_symbols
        # 重新运行主循环
        print("\n开始重新下载未完成的交易对...")
# Out:
# 已扫描到 111251 个现有文件
# 将处理以下交易对: ['BTC/USDT:USDT', 'ETH/USDT:USDT', 
USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance BB/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance NOT/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance TURBO/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance IO/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance ZK/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance MEW/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance LISTA/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance ZRO/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance RENDER/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance BANANA/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance RARE/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance G/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance SYN/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance SYS/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance VOXEL/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance BRETT/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance ALPACA/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance POPCAT/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance SUN/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance VIDT/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance NULS/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance DOGS/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance MBOX/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance CHESS/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance FLUX/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance BSW/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance QUICK/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance NEIROETH/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance RPL/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance AERGO/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance POL/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance UXLINK/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance 1MBABYDOGE/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance NEIRO/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance KDA/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance FIDA/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance FIO/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance CATI/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance GHST/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance LOKA/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance HMSTR/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance BTC/USDT:USDT-250328 1m 2025-02-08 的数据
# 正在获取 binance ETH/USDT:USDT-250328 1m 2025-02-08 的数据
# 正在获取 binance REI/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance COS/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance EIGEN/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance DIA/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance 1000CAT/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance SCR/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance GOAT/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance MOODENG/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance SAFE/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance SANTOS/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance TROY/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance PONKE/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance COW/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance CETUS/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance 1000000MOG/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance GRASS/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance DRIFT/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance SWELL/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance ACT/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance PNUT/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance HIPPO/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance 1000X/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance DEGEN/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance BAN/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance AKT/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance SLERF/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance SCRT/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance 1000CHEEMS/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance 1000WHY/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance THE/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance MORPHO/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance CHILLGUY/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance KAIA/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance AERO/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance ACX/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance ORCA/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance MOVE/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance RAYSOL/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance KOMA/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance VIRTUAL/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance SPX/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance ME/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance AVA/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance DEGO/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance VELODROME/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance MOCA/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance VANA/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance PENGU/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance LUMIA/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance USUAL/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance AIXBT/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance FARTCOIN/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance KMNO/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance CGPT/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance HIVE/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance DEXE/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance BTC/USDT:USDT-250627 1m 2025-02-08 的数据
# 正在获取 binance ETH/USDT:USDT-250627 1m 2025-02-08 的数据
# 正在获取 binance PHA/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance DF/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance GRIFFAIN/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance AI16Z/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance ZEREBRO/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance BIO/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance COOKIE/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance ALCH/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance SWARMS/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance SONIC/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance D/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance PROM/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance S/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance SOLV/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance ARC/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance AVAAI/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance TRUMP/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance MELANIA/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance VTHO/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance ANIME/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance VINE/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance PIPPIN/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance VVV/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance BERA/USDT:USDT 1m 2025-02-08 的数据
# 正在获取 binance BERA/USDT:USDT 1m 2025-02-05 的数据
# BERA/USDT:USDT 在 2025-02-05 筛选后无数据
#
# 开始分析下载情况...
# 已扫描到 111377 个现有文件
#
# 下载统计信息:
# BTC/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ETH/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BCH/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# XRP/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# EOS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# LTC/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# TRX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ETC/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# LINK/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# XLM/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ADA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# XMR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DASH/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ZEC/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# XTZ/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BNB/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ATOM/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ONT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# IOTA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BAT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# VET/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# NEO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# QTUM/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# IOST/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# THETA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ALGO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ZIL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# KNC/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ZRX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# COMP/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# OMG/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DOGE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SXP/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# KAVA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BAND/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# RLC/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# WAVES/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MKR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SNX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DOT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DEFI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# YFI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BAL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CRV/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# TRB/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# RUNE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SUSHI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# EGLD/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SOL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ICX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# STORJ/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BLZ/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# UNI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AVAX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# FTM/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ENJ/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# FLM/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# REN/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# KSM/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# NEAR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AAVE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# FIL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# RSR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# LRC/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# OCEAN/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CVC/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BEL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CTK/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AXS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ALPHA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ZEN/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SKL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# GRT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# 1INCH/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CHZ/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SAND/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ANKR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# LIT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# UNFI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# REEF/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# RVN/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SFP/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# XEM/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BTCST/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# COTI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CHR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MANA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ALICE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# HBAR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ONE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# LINA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# STMX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DENT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CELR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# HOT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MTL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# OGN/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# NKN/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SC/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DGB/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# 1000SHIB/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BAKE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# GTC/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BTCDOM/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# IOTX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# RAY/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# C98/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MASK/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ATA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DYDX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# 1000XEC/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# GALA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CELO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# KLAY/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ARPA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CTSI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# LPT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ENS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# PEOPLE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ROSE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DUSK/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# FLOW/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# IMX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# API3/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# GMT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# APE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# WOO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# FTT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# JASMY/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DAR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# OP/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# INJ/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# STG/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SPELL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# 1000LUNC/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# LUNA2/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# LDO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CVX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ICP/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# APT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# QNT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# FET/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# FXS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# HOOK/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MAGIC/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# T/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# HIGH/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MINA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ASTR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AGIX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# PHB/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# GMX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CFX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# STX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BNX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ACH/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SSV/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CKB/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# PERP/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# TRU/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# LQTY/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# USDC/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ID/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ARB/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# JOE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# TLM/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AMB/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# LEVER/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# RDNT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# HFT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# XVS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BLUR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# EDU/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# IDEX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SUI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# 1000PEPE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# 1000FLOKI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# UMA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# RAD/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# KEY/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# COMBO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# NMR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MAV/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MDT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# XVG/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# WLD/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# PENDLE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ARKM/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AGLD/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# YGG/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DODOX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BNT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# OXT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SEI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CYBER/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# HIFI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ARK/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# GLMR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BICO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# STRAX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# LOOM/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BIGTIME/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BOND/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ORBS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# STPT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# WAXP/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BSV/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# RIF/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# POLYX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# GAS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# POWR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SLP/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# TIA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SNT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CAKE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MEME/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# TWT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# TOKEN/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ORDI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# STEEM/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BADGER/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ILV/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# NTRN/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# KAS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BEAMX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# 1000BONK/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# PYTH/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SUPER/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# USTC/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ONG/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ETHW/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# JTO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# 1000SATS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AUCTION/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# 1000RATS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ACE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MOVR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# NFP/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# XAI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# WIF/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MANTA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ONDO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# LSK/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ALT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# JUP/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ZETA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# RONIN/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DYM/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# OM/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# PIXEL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# STRK/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MAVIA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# GLM/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# PORTAL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# TON/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AXL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MYRO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# METIS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AEVO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# VANRY/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BOME/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ETHFI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ENA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# W/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# TNSR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SAGA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# TAO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# OMNI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# REZ/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BB/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# NOT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# TURBO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# IO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ZK/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MEW/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# LISTA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ZRO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# RENDER/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BANANA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# RARE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# G/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SYN/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SYS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# VOXEL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BRETT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ALPACA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# POPCAT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SUN/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# VIDT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# NULS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DOGS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MBOX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CHESS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# FLUX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BSW/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# QUICK/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# NEIROETH/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# RPL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AERGO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# POL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# UXLINK/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# 1MBABYDOGE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# NEIRO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# KDA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# FIDA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# FIO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CATI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# GHST/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# LOKA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# HMSTR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BTC/USDT:USDT-250328: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ETH/USDT:USDT-250328: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# REI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# COS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# EIGEN/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DIA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# 1000CAT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SCR/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# GOAT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MOODENG/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SAFE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SANTOS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# TROY/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# PONKE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# COW/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CETUS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# 1000000MOG/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# GRASS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DRIFT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SWELL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ACT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# PNUT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# HIPPO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# 1000X/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DEGEN/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BAN/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AKT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SLERF/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SCRT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# 1000CHEEMS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# 1000WHY/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# THE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MORPHO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CHILLGUY/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# KAIA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AERO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ACX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ORCA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MOVE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# RAYSOL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# KOMA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# VIRTUAL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SPX/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ME/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AVA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DEGO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# VELODROME/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MOCA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# VANA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# PENGU/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# LUMIA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# USUAL/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AIXBT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# FARTCOIN/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# KMNO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# CGPT/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# HIVE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DEXE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BTC/USDT:USDT-250627: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ETH/USDT:USDT-250627: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# PHA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# DF/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# GRIFFAIN/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AI16Z/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ZEREBRO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BIO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# COOKIE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ALCH/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SWARMS/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SONIC/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# D/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# PROM/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# S/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# SOLV/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ARC/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# AVAAI/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# TRUMP/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# MELANIA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# VTHO/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# ANIME/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# VINE/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# PIPPIN/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# VVV/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
# BERA/USDT:USDT: 完成率 0.00% (0/4)
#   缺失数据: ['2025-02-08_1m', '2025-02-07_1m', '2025-02-06_1m', '2025-02-05_1m']
#
# 未完全下载的交易对数量: 396/396
#
# 是否要重新下载未完成的交易对？(y/n)
#
# 开始重新下载未完成的交易对...
