# %% [markdown]
# Parameter Heatmap
# ==========
#
# This tutorial will show how to optimize strategies with multiple parameters and how to examine and reason about optimization results.
# It is assumed you're already familiar with
# [basic _backtesting.py_ usage](https://kernc.github.io/backtesting.py/doc/examples/Quick%20Start%20User%20Guide.html).
#
# First, let's again import our helper moving average function.
# In practice, one should use functions from an indicator library, such as
# [TA-Lib](https://github.com/mrjbq7/ta-lib) or
# [Tulipy](https://tulipindicators.org).

# %%
# %pip show sambo
import sambo
# Out:
# Name: sambo
# Version: 1.25.0
# Summary: Sequential And Model-Based Optimization
# Home-page: https://sambo-optimization.github.io
# Author:
# Author-email:
# License: AGPL-3.0
# Location: c:\users\x7498\anaconda3\envs\backtesting\lib\site-packages
# Requires: numpy, scipy
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# 1. 导入必要的库
import pandas as pd
import os
from datetime import datetime
from glob import glob

def load_and_resample_data(symbol, start_date, end_date, source_timeframe='1m', target_timeframe='30m', data_path=r'\\znas\Main\future'):
    """
    加载并重采样期货数据
    
    参数:
        symbol (str): 交易对名称，如 'KASUSDT'
        start_date (str): 开始日期，格式 'YYYY-MM-DD'
        end_date (str): 结束日期，格式 'YYYY-MM-DD'
        source_timeframe (str): 源数据时间周期，默认 '1m'
        target_timeframe (str): 目标时间周期，默认 '30m'
        data_path (str): 数据文件路径
        
    返回:
        pd.DataFrame: 符合backtesting.py格式的DataFrame
    """
    # 生成日期范围
    date_range = pd.date_range(start=start_date, end=end_date, freq='D')
    
    # 准备存储所有数据的列表
    all_data = []
    
    # 标准化交易对名称
    formatted_symbol = symbol.replace('/', '_').replace(':', '_')
    if not formatted_symbol.endswith('USDT'):
        formatted_symbol = f"{formatted_symbol}USDT"
    
    # 遍历每一天
    for date in date_range:
        date_str = date.strftime('%Y-%m-%d')
        # 构建文件路径
        file_path = os.path.join(data_path, date_str, f"{date_str}_{formatted_symbol}_USDT_{source_timeframe}.csv")
        
        try:
            if os.path.exists(file_path):
                # 读取数据
                df = pd.read_csv(file_path)
                df['datetime'] = pd.to_datetime(df['datetime'])
                all_data.append(df)
            else:
                print(f"文件不存在: {file_path}")
        except Exception as e:
            print(f"读取文件出错 {file_path}: {str(e)}")
            continue
    
    if not all_data:
        raise ValueError(f"未找到 {symbol} 在指定日期范围内的数据")
    
    # 合并所有数据
    combined_df = pd.concat(all_data, ignore_index=True)
    combined_df = combined_df.sort_values('datetime')
    
    # 设置时间索引
    combined_df.set_index('datetime', inplace=True)
    
    # 重采样到目标时间周期
    resampled = combined_df.resample(target_timeframe).agg({
        'open': 'first',
        'high': 'max',
        'low': 'min',
        'close': 'last',
        'volume': 'sum'
    }).dropna()  # 立即删除NaN值
    
    # 转换为backtesting.py格式
    backtesting_df = pd.DataFrame({
        'Open': resampled['open'],
        'High': resampled['high'],
        'Low': resampled['low'],
        'Close': resampled['close'],
        'Volume': resampled['volume']
    })
    
    # 确保所有数据都是数值类型并删除任何无效值
    for col in ['Open', 'High', 'Low', 'Close', 'Volume']:
        backtesting_df[col] = pd.to_numeric(backtesting_df[col], errors='coerce')
    
    # 最终清理
    backtesting_df = backtesting_df.dropna()
    
    return backtesting_df

# %% [markdown]
# Our strategy will be a similar moving average cross-over strategy to the one in
# [Quick Start User Guide](https://kernc.github.io/backtesting.py/doc/examples/Quick%20Start%20User%20Guide.html),
# but we will use four moving averages in total:
# two moving averages whose relationship determines a general trend
# (we only trade long when the shorter MA is above the longer one, and vice versa),
# and two moving averages whose cross-over with daily _close_ prices determine the signal to enter or exit the position.

# %%
# 加载数据
symbol = 'KASUSDT'
start_date = '2024-01-01'
end_date = '2025-01-01'

try:
    backtesting_df = load_and_resample_data(
        symbol=symbol,
        start_date=start_date,
        end_date=end_date,
        source_timeframe='1m',
        target_timeframe='30min'
    )
    
    print(f"数据加载成功:")
    print(f"时间范围: {backtesting_df.index.min()} 到 {backtesting_df.index.max()}")
    print(f"数据条数: {len(backtesting_df)}")
    print("\n数据示例:")
    print(backtesting_df.head())
    
except Exception as e:
    print(f"处理数据时出错: {str(e)}")
# Out:
# 文件不存在: \\znas\Main\future\2024-01-01\2024-01-01_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-02\2024-01-02_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-03\2024-01-03_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-04\2024-01-04_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-05\2024-01-05_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-06\2024-01-06_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-07\2024-01-07_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-08\2024-01-08_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-09\2024-01-09_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-10\2024-01-10_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-11\2024-01-11_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-12\2024-01-12_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-13\2024-01-13_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-14\2024-01-14_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-15\2024-01-15_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-16\2024-01-16_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-17\2024-01-17_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-18\2024-01-18_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-19\2024-01-19_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-20\2024-01-20_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-21\2024-01-21_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-22\2024-01-22_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-23\2024-01-23_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-24\2024-01-24_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-25\2024-01-25_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-26\2024-01-26_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-27\2024-01-27_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-28\2024-01-28_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-29\2024-01-29_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-30\2024-01-30_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-01-31\2024-01-31_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-01\2024-02-01_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-02\2024-02-02_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-03\2024-02-03_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-04\2024-02-04_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-05\2024-02-05_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-06\2024-02-06_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-07\2024-02-07_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-08\2024-02-08_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-09\2024-02-09_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-10\2024-02-10_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-11\2024-02-11_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-12\2024-02-12_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-13\2024-02-13_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-14\2024-02-14_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-15\2024-02-15_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-16\2024-02-16_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-17\2024-02-17_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-18\2024-02-18_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-19\2024-02-19_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-20\2024-02-20_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-21\2024-02-21_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-22\2024-02-22_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-23\2024-02-23_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-24\2024-02-24_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-25\2024-02-25_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-26\2024-02-26_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-27\2024-02-27_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-28\2024-02-28_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-02-29\2024-02-29_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-01\2024-03-01_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-02\2024-03-02_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-03\2024-03-03_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-04\2024-03-04_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-05\2024-03-05_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-06\2024-03-06_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-07\2024-03-07_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-08\2024-03-08_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-09\2024-03-09_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-10\2024-03-10_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-11\2024-03-11_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-12\2024-03-12_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-13\2024-03-13_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-14\2024-03-14_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-15\2024-03-15_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-16\2024-03-16_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-17\2024-03-17_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-18\2024-03-18_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-19\2024-03-19_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-20\2024-03-20_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-21\2024-03-21_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-22\2024-03-22_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-23\2024-03-23_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-24\2024-03-24_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-25\2024-03-25_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-26\2024-03-26_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-27\2024-03-27_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-28\2024-03-28_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-29\2024-03-29_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-30\2024-03-30_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-03-31\2024-03-31_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-01\2024-04-01_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-02\2024-04-02_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-03\2024-04-03_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-04\2024-04-04_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-05\2024-04-05_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-06\2024-04-06_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-07\2024-04-07_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-08\2024-04-08_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-09\2024-04-09_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-10\2024-04-10_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-11\2024-04-11_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-12\2024-04-12_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-13\2024-04-13_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-14\2024-04-14_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-15\2024-04-15_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-16\2024-04-16_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-17\2024-04-17_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-18\2024-04-18_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-19\2024-04-19_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-20\2024-04-20_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-21\2024-04-21_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-22\2024-04-22_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-23\2024-04-23_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-24\2024-04-24_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-25\2024-04-25_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-26\2024-04-26_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-27\2024-04-27_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-28\2024-04-28_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-29\2024-04-29_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-04-30\2024-04-30_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-01\2024-05-01_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-02\2024-05-02_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-03\2024-05-03_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-04\2024-05-04_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-05\2024-05-05_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-06\2024-05-06_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-07\2024-05-07_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-08\2024-05-08_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-09\2024-05-09_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-10\2024-05-10_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-11\2024-05-11_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-12\2024-05-12_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-13\2024-05-13_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-14\2024-05-14_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-15\2024-05-15_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-16\2024-05-16_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-17\2024-05-17_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-18\2024-05-18_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-19\2024-05-19_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-20\2024-05-20_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-21\2024-05-21_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-22\2024-05-22_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-23\2024-05-23_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-24\2024-05-24_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-25\2024-05-25_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-26\2024-05-26_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-27\2024-05-27_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-28\2024-05-28_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-29\2024-05-29_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-30\2024-05-30_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-05-31\2024-05-31_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-01\2024-06-01_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-02\2024-06-02_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-03\2024-06-03_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-04\2024-06-04_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-05\2024-06-05_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-06\2024-06-06_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-07\2024-06-07_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-08\2024-06-08_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-09\2024-06-09_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-10\2024-06-10_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-11\2024-06-11_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-12\2024-06-12_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-13\2024-06-13_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-14\2024-06-14_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-15\2024-06-15_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-16\2024-06-16_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-17\2024-06-17_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-18\2024-06-18_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-19\2024-06-19_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-20\2024-06-20_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-21\2024-06-21_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-22\2024-06-22_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-23\2024-06-23_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-24\2024-06-24_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-25\2024-06-25_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-26\2024-06-26_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-27\2024-06-27_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-28\2024-06-28_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-29\2024-06-29_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-06-30\2024-06-30_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-01\2024-07-01_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-02\2024-07-02_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-03\2024-07-03_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-04\2024-07-04_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-05\2024-07-05_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-06\2024-07-06_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-07\2024-07-07_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-08\2024-07-08_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-09\2024-07-09_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-10\2024-07-10_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-11\2024-07-11_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-12\2024-07-12_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-13\2024-07-13_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-14\2024-07-14_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-15\2024-07-15_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-16\2024-07-16_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-17\2024-07-17_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-18\2024-07-18_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-19\2024-07-19_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-20\2024-07-20_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-21\2024-07-21_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-22\2024-07-22_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-23\2024-07-23_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-24\2024-07-24_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-25\2024-07-25_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-26\2024-07-26_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-27\2024-07-27_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-28\2024-07-28_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-29\2024-07-29_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-30\2024-07-30_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-07-31\2024-07-31_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-01\2024-08-01_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-02\2024-08-02_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-03\2024-08-03_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-04\2024-08-04_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-05\2024-08-05_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-06\2024-08-06_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-07\2024-08-07_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-08\2024-08-08_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-09\2024-08-09_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-10\2024-08-10_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-11\2024-08-11_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-12\2024-08-12_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-13\2024-08-13_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-14\2024-08-14_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-15\2024-08-15_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-16\2024-08-16_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-17\2024-08-17_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-18\2024-08-18_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-19\2024-08-19_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-20\2024-08-20_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-21\2024-08-21_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-22\2024-08-22_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-23\2024-08-23_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-24\2024-08-24_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-25\2024-08-25_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-26\2024-08-26_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-27\2024-08-27_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-28\2024-08-28_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-29\2024-08-29_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-30\2024-08-30_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-08-31\2024-08-31_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-01\2024-09-01_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-02\2024-09-02_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-03\2024-09-03_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-04\2024-09-04_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-05\2024-09-05_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-06\2024-09-06_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-07\2024-09-07_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-08\2024-09-08_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-09\2024-09-09_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-10\2024-09-10_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-11\2024-09-11_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-12\2024-09-12_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-13\2024-09-13_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-14\2024-09-14_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-15\2024-09-15_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-16\2024-09-16_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-17\2024-09-17_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-18\2024-09-18_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-19\2024-09-19_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-20\2024-09-20_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-21\2024-09-21_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-22\2024-09-22_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-23\2024-09-23_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-24\2024-09-24_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-25\2024-09-25_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-26\2024-09-26_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-27\2024-09-27_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-28\2024-09-28_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-29\2024-09-29_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-09-30\2024-09-30_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-01\2024-10-01_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-02\2024-10-02_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-03\2024-10-03_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-04\2024-10-04_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-05\2024-10-05_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-06\2024-10-06_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-07\2024-10-07_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-08\2024-10-08_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-09\2024-10-09_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-10\2024-10-10_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-11\2024-10-11_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-12\2024-10-12_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-13\2024-10-13_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-14\2024-10-14_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-15\2024-10-15_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-16\2024-10-16_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-17\2024-10-17_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-18\2024-10-18_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-19\2024-10-19_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-20\2024-10-20_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-21\2024-10-21_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-22\2024-10-22_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-23\2024-10-23_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-24\2024-10-24_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-25\2024-10-25_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-26\2024-10-26_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-27\2024-10-27_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-28\2024-10-28_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-29\2024-10-29_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-30\2024-10-30_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-10-31\2024-10-31_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-01\2024-11-01_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-02\2024-11-02_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-03\2024-11-03_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-04\2024-11-04_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-05\2024-11-05_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-06\2024-11-06_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-07\2024-11-07_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-08\2024-11-08_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-09\2024-11-09_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-10\2024-11-10_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-11\2024-11-11_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-12\2024-11-12_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-13\2024-11-13_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-14\2024-11-14_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-15\2024-11-15_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-16\2024-11-16_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-17\2024-11-17_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-18\2024-11-18_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-19\2024-11-19_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-20\2024-11-20_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-21\2024-11-21_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-22\2024-11-22_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-23\2024-11-23_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-24\2024-11-24_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-25\2024-11-25_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-26\2024-11-26_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-27\2024-11-27_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-28\2024-11-28_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-29\2024-11-29_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-11-30\2024-11-30_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-01\2024-12-01_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-02\2024-12-02_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-03\2024-12-03_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-04\2024-12-04_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-05\2024-12-05_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-06\2024-12-06_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-07\2024-12-07_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-08\2024-12-08_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-09\2024-12-09_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-10\2024-12-10_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-11\2024-12-11_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-12\2024-12-12_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-13\2024-12-13_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-14\2024-12-14_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-15\2024-12-15_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-16\2024-12-16_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-17\2024-12-17_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-18\2024-12-18_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-19\2024-12-19_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-20\2024-12-20_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-21\2024-12-21_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-22\2024-12-22_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-23\2024-12-23_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-24\2024-12-24_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-25\2024-12-25_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-26\2024-12-26_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-27\2024-12-27_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-28\2024-12-28_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-29\2024-12-29_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-30\2024-12-30_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2024-12-31\2024-12-31_KASUSDT_USDT_1m.csv
# 文件不存在: \\znas\Main\future\2025-01-01\2025-01-01_KASUSDT_USDT_1m.csv
# 处理数据时出错: 未找到 KASUSDT 在指定日期范围内的数据

# %%
from Strategies.EnhancedReversalStrategy import EnhancedReversalStrategy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from Strategies.EnhancedReversalStrategy import EnhancedReversalStrategy
#
# ModuleNotFoundError: No module named 'Strategies'

# %% [markdown]
# It's not a robust strategy, but we can optimize it.
#
# [Grid search](https://en.wikipedia.org/wiki/Hyperparameter_optimization#Grid_search)
# is an exhaustive search through a set of specified sets of values of hyperparameters. One evaluates the performance for each set of parameters and finally selects the combination that performs best.
#
# Let's optimize our strategy on Google stock data using _randomized_ grid search over the parameter space, evaluating at most (approximately) 200 randomly chosen combinations:

# %%
# 使用自定义评分函数(推荐)
def custom_score(stats):
    """
    自定义评分函数，综合考虑多个指标
    """
    # 获取关键指标
    sharpe = stats['Sharpe Ratio']
    max_dd = stats['Max. Drawdown [%]']
    ret = stats['Return [%]']
    win_rate = stats['Win Rate [%]']
    sqn = stats['SQN']  # 假设stats中包含SQN指标
    trades = stats['# Trades']  # 假设stats中包含交易次数指标
    
    # 对最大回撤进行惩罚（回撤越大，分数越低）
    dd_penalty = 1 / (1 + abs(max_dd/100))
    
    # 对交易次数进行惩罚（交易次数少于50次，分数越低）
    trade_penalty = 1 if trades >= 50 else trades / 50
    
    # 计算综合得分
    score = (
        0.4 * (ret/100) +          # 40% 权重给收益率
        0.2 * sqn +                # 20% 权重给SQN
        0.2 * sharpe +             # 20% 权重给夏普比率
        0.1 * (win_rate/100) +     # 10% 权重给胜率
        0.1 * dd_penalty           # 10% 权重给回撤惩罚项
    ) * trade_penalty              # 乘以交易次数惩罚项
    
    return score

# %% [markdown]
# Notice `return_heatmap=True` parameter passed to
# [`Backtest.optimize()`](https://kernc.github.io/backtesting.py/doc/backtesting/backtesting.html#backtesting.backtesting.Backtest.optimize).
# It makes the function return a heatmap series along with the usual stats of the best run.
# `heatmap` is a pandas Series indexed with a MultiIndex, a cartesian product of all permissible (tried) parameter values.
# The series values are from the `maximize=` argument we provided.

# %% [markdown]
# This heatmap contains the results of all the runs,
# making it very easy to obtain parameter combinations for e.g. three best runs:

# %% [markdown]
# But we use vision to make judgements on larger data sets much faster.
# Let's plot the whole heatmap by projecting it on two chosen dimensions.
# Say we're mostly interested in how parameters `n1` and `n2`, on average, affect the outcome.

# %% [markdown]
# Let's plot this table as a heatmap:

# %% [markdown]
# We see that, on average, we obtain the highest result using trend-determining parameters `n1=30` and `n2=100` or `n1=70` and `n2=80`,
# and it's not like other nearby combinations work similarly well — for our particular strategy, these combinations really stand out.
#
# Since our strategy contains several parameters, we might be interested in other relationships between their values.
# We can use
# [`backtesting.lib.plot_heatmaps()`](https://kernc.github.io/backtesting.py/doc/backtesting/lib.html#backtesting.lib.plot_heatmaps)
# function to plot interactive heatmaps of all parameter combinations simultaneously.

# %% [markdown]
# ## Model-based optimization
#
# Above, we used _randomized grid search_ optimization method. Any kind of grid search, however, might be computationally expensive for large data sets. In the follwing example, we will use
# [_SAMBO Optimization_](https://sambo-optimization.github.io)
# package to guide our optimization better informed using forests of decision trees.
# The hyperparameter model is sequentially improved by evaluating the expensive function (the backtest) at the next best point, thereby hopefully converging to a set of optimal parameters with **as few evaluations as possible**.
#
# So, with `method="sambo"`:

# %%
import sys
print(sys.path)
# Out:
# ['c:\\Users\\x7498\\anaconda3\\envs\\backtesting\\python310.zip', 'c:\\Users\\x7498\\anaconda3\\envs\\backtesting\\DLLs', 'c:\\Users\\x7498\\anaconda3\\envs\\backtesting\\lib', 'c:\\Users\\x7498\\anaconda3\\envs\\backtesting', '', 'c:\\Users\\x7498\\anaconda3\\envs\\backtesting\\lib\\site-packages', 'c:\\Users\\x7498\\anaconda3\\envs\\backtesting\\lib\\site-packages\\win32', 'c:\\Users\\x7498\\anaconda3\\envs\\backtesting\\lib\\site-packages\\win32\\lib', 'c:\\Users\\x7498\\anaconda3\\envs\\backtesting\\lib\\site-packages\\Pythonwin', 'c:\\Users\\x7498\\anaconda3\\envs\\backtesting\\lib\\site-packages\\setuptools\\_vendor']

# %%
from backtesting import Backtest

# 初始化回测实例
backtest = Backtest(
    backtesting_df,  # 输入的OHLCV数据
    EnhancedReversalStrategy,  # 使用我们的反转策略类
    commission=.0004,  # 手续费万分之四
    exclusive_orders=True,  # 每次交易前先平掉旧仓位
    cash=1000,  # 初始资金
    margin=1/8  # 设置保证金比例为1/8,相当于8倍杠杆
)

# 使用sambo优化
stats, heatmap, optimize_result = backtest.optimize(
    lowest_point_bars=range(5, 321, 5),  # 使用range生成整数范围
    rsi_length=range(2, 221, 5),
    sell_barrier=range(70, 176, 5),  # 调整卖出阈值范围与策略参数一致
    vwma_period=range(20, 322, 10),
    max_dca_times=range(4, 12, 1),  # 改为可优化参数范围
    constraint=lambda p: True,
    maximize=custom_score,
    method='sambo',  # 指定使用sambo方法
    max_tries=10,  # 可以增加尝试次数以提高优化效果
    random_state=0,
    return_heatmap=True,
    return_optimization=True
)
# Out:
# ['c:\\Users\\x7498\\anaconda3\\envs\\backtesting\\python310.zip', 'c:\\Users\\x7498\\anaconda3\\envs\\backtesting\\DLLs', 'c:\\Users\\x7498\\anaconda3\\envs\\backtesting\\lib', 'c:\\Users\\x7498\\anaconda3\\envs\\backtesting', '', 'c:\\Users\\x7498\\anaconda3\\envs\\backtesting\\lib\\site-packages', 'c:\\Users\\x7498\\anaconda3\\envs\\backtesting\\lib\\site-packages\\win32', 'c:\\Users\\x7498\\anaconda3\\envs\\backtesting\\lib\\site-packages\\win32\\lib', 'c:\\Users\\x7498\\anaconda3\\envs\\backtesting\\lib\\site-packages\\Pythonwin', 'c:\\Users\\x7498\\anaconda3\\envs\\backtesting\\lib\\site-packages\\setuptools\\_vendor']
# Backtest.optimize:   0%|          | 0/200 [00:00<?, ?it/s]

# %%
heatmap.sort_values().iloc[-5:]
# Out:
# lowest_point_bars  rsi_length  sell_barrier  vwma_period  max_dca_times  leverage
# 287                81          65            318          8              8           3578.354495
# 320                81          65            320          8              8           3581.970030
# 289                107         65            314          8              8           3847.663523
# 320                107         65            320          8              8           3851.604803
# 273                107         65            320          8              8           3896.659851
# Name: Equity Final [$], dtype: float64

# %% [markdown]
# Notice how the optimization runs somewhat slower even though `max_tries=` is lower. This is due to the sequential nature of the algorithm and should actually perform quite comparably even in cases of _much larger parameter spaces_ where grid search would effectively blow up, likely reaching a better optimum than a simple randomized search would.
# A note of warning, again, to take steps to avoid
# [overfitting](https://en.wikipedia.org/wiki/Overfitting)
# insofar as possible.
#
# Understanding the impact of each parameter on the computed objective function is easy in two dimensions, but as the number of dimensions grows, partial dependency plots are increasingly useful.
# [Plotting tools from _SAMBO_](https://sambo-optimization.github.io/doc/sambo/plot.html)
# take care of the more mundane things needed to make good and informative plots of the parameter space.
#
# Note, because SAMBO internally only does _minimization_, the values in `optimize_result` are negated (less is better).

# %%
from sambo.plot import plot_objective

# 更新参数名称以匹配你想要显示的参数（添加max_dca_times参数）
names = ['lowest_point_bars', 'rsi_length', 'sell_barrier', 'vwma_period', 'max_dca_times']
_ = plot_objective(optimize_result, names=names, estimator='et')

# %%
from sambo.plot import plot_evaluations

_ = plot_evaluations(optimize_result, names=names)

# %% [markdown]
# Learn more by exploring further
# [examples](https://kernc.github.io/backtesting.py/doc/backtesting/index.html#tutorials)
# or find more framework options in the
# [full API reference](https://kernc.github.io/backtesting.py/doc/backtesting/index.html#header-submodules).

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# 创建三维散点图
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111, projection='3d')

# 获取参数值
points = heatmap.index.to_frame()
scores = heatmap.values

# 创建散点图，用颜色表示得分
scatter = ax.scatter(points['lowest_point_bars'], 
                    points['rsi_length'], 
                    points['vwma_period'],
                    c=scores,
                    cmap='viridis',
                    s=100)  # 点的大小

# 设置标签
ax.set_xlabel('Lookback Period (5-320)')  # 修改参数说明
ax.set_ylabel('RSI Period (2-220)')       # 修改参数说明
ax.set_zlabel('VWMA Window (20-320)')     # 修改参数说明

# 添加颜色条
plt.colorbar(scatter, label='Performance Score')  # 修改评分名称

# 设置标题
plt.title('3D Parameter Optimization Surface (Strategy v2.1)')  # 更新标题

# 调整视角以获得更好的视觉效果
ax.view_init(elev=20, azim=45)

# 添加网格线
ax.grid(True)

plt.show()

# 打印优化结果
print("\nTop 5 Parameter Combinations (Optimized):")
top_5 = heatmap.sort_values(ascending=False).head(5)
for idx, score in top_5.items():
    print(f"\nScore: {score:.4f}")
    print(f"Lookback Window: {idx[0]}")          # 参数名称修改
    print(f"RSI Period: {idx[1]}")               # 参数名称修改
    print(f"VWMA Window: {idx[2]}")              # 参数名称修改
    print(f"RSI Sell Threshold: {idx[3]}")       # 参数名称修改
    print(f"Max DCA Steps: {idx[4]}")             # 参数名称修改
    print(f"Position Multiplier: {idx[5]}")      # 参数名称修改
# Out:
# Top 5 Parameter Combinations (Custom Score):
#
# Score: 3896.6599
# Lowest Point Bars: 273
# RSI Length: 107
# VWMA Period: 65
# Sell Barrier: 320
# Max DCA Times: 8
# Leverage: 8
#
# Score: 3851.6048
# Lowest Point Bars: 320
# RSI Length: 107
# VWMA Period: 65
# Sell Barrier: 320
# Max DCA Times: 8
# Leverage: 8
#
# Score: 3847.6635
# Lowest Point Bars: 289
# RSI Length: 107
# VWMA Period: 65
# Sell Barrier: 314
# Max DCA Times: 8
# Leverage: 8
#
# Score: 3581.9700
# Lowest Point Bars: 320
# RSI Length: 81
# VWMA Period: 65
# Sell Barrier: 320
# Max DCA Times: 8
# Leverage: 8
#
# Score: 3578.3545
# Lowest Point Bars: 287
# RSI Length: 81
# VWMA Period: 65
# Sell Barrier: 318
# Max DCA Times: 8
# Leverage: 8

# %%
# 可选：添加二维投影图
fig = plt.figure(figsize=(15, 5))

# Lowest Point Bars vs RSI Length
plt.subplot(161)
plt.scatter(points['lowest_point_bars'], 
           points['rsi_length'], 
           c=scores, 
           cmap='viridis')
plt.xlabel('Lookback Period')
plt.ylabel('RSI Period') 
plt.colorbar(label='Score')

# Lowest Point Bars vs VWMA Period
plt.subplot(162)
plt.scatter(points['lowest_point_bars'],
           points['vwma_period'],
           c=scores,
           cmap='viridis')
plt.xlabel('Lookback Period')
plt.ylabel('VWMA Window')
plt.colorbar(label='Score')

# RSI Length vs VWMA Period  
plt.subplot(163)
plt.scatter(points['rsi_length'],
           points['vwma_period'],
           c=scores,
           cmap='viridis')
plt.xlabel('RSI Period')
plt.ylabel('VWMA Window')
plt.colorbar(label='Score')

# Lowest Point Bars vs Sell Barrier
plt.subplot(164)
plt.scatter(points['lowest_point_bars'],
           points['sell_barrier'], 
           c=scores,
           cmap='viridis')
plt.xlabel('Lookback Period')
plt.ylabel('RSI Sell Threshold')
plt.colorbar(label='Score')

# RSI Length vs Sell Barrier
plt.subplot(165)
plt.scatter(points['rsi_length'],
           points['sell_barrier'],
           c=scores, 
           cmap='viridis')
plt.xlabel('RSI Period')
plt.ylabel('RSI Sell Threshold')
plt.colorbar(label='Score')

# VWMA Period vs Sell Barrier
plt.subplot(166)
plt.scatter(points['vwma_period'],
           points['sell_barrier'],
           c=scores,
           cmap='viridis')
plt.xlabel('VWMA Window')
plt.ylabel('RSI Sell Threshold')
plt.colorbar(label='Score')

plt.tight_layout()
plt.show()

# %%
from backtesting import Backtest

# 初始化回测实例
bt = Backtest(
    backtesting_df,
    EnhancedReversalStrategy,
    commission=.0004,
    margin=1/8,  # 8倍杠杆
    trade_on_close=True,  # 与TradingView的process_orders_on_close一致
    exclusive_orders=True,
    hedging=False  # 禁止对冲
)


# 使用最优参数运行回测
stats = bt.run(
    lowest_point_bars=273,
    rsi_length=107,
    sell_barrier=65,
    vwma_period=320,
    max_dca_times=8
)
# 打印回测统计结果
print("\n=== 回测结果 ===")
print(f"总收益率: {stats['Return [%]']:.2f}%")
print(f"夏普比率: {stats['Sharpe Ratio']:.2f}")
print(f"最大回撤: {stats['Max. Drawdown [%]']:.2f}%") 
print(f"胜率: {stats['Win Rate [%]']:.2f}%")
print(f"总交易次数: {stats['# Trades']}")
# Out:
# === 回测结果 ===
# 总收益率: 85.86%
# 夏普比率: 1.82
# 最大回撤: -15.31%
# 胜率: 36.03%
# 总交易次数: 136
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# 从heatmap获取最优参数组合
best_idx = heatmap.sort_values(ascending=False).index[0]
best_params = {
    'lowest_point_bars': best_idx[0],
    'rsi_length': best_idx[1], 
    'sell_barrier': best_idx[2],
    'vwma_period': best_idx[3],
    'max_dca_times': best_idx[4]
}

# 打印最优参数
print("\n=== 最优参数 ===")
print(f"最低点周期: {best_params['lowest_point_bars']}")
print(f"RSI周期: {best_params['rsi_length']}")
print(f"RSI卖出阈值: {best_params['sell_barrier']}")
print(f"VWMA周期: {best_params['vwma_period']}")
print(f"最大DCA次数: {best_params['max_dca_times']}")

# 使用最优参数运行回测
stats = bt.run(
    lowest_point_bars=best_params['lowest_point_bars'],
    rsi_length=best_params['rsi_length'],
    sell_barrier=best_params['sell_barrier'],
    vwma_period=best_params['vwma_period'],
    max_dca_times=best_params['max_dca_times']
)

# 打印回测统计结果
print("\n=== 回测结果 ===")
print(f"总收益率: {stats['Return [%]']:.2f}%")
print(f"夏普比率: {stats['Sharpe Ratio']:.2f}")
print(f"最大回撤: {stats['Max. Drawdown [%]']:.2f}%") 
print(f"胜率: {stats['Win Rate [%]']:.2f}%")
print(f"总交易次数: {stats['# Trades']}")

# 显示回测可视化结果
try:
    bt.plot(resample=False) # 禁用重采样以避免日期时间转换错误
except TypeError as e:
    print("警告: 绘图错误,可能是由于数据类型转换问题")
    print(f"错误信息: {str(e)}")
